# %% [markdown]
# 햄버거 가게에서 일을 하는 상수는 햄버거를 포장하는 일을 합니다. 함께 일을 하는 다른 직원들이 햄버거에 들어갈 재료를 조리해 주면 조리된 순서대로 상수의 앞에 아래서부터 위로 쌓이게 되고, 상수는 순서에 맞게 쌓여서 완성된 햄버거를 따로 옮겨 포장을 하게 됩니다. 상수가 일하는 가게는 정해진 순서(아래서부터, 빵 – 야채 – 고기 - 빵)로 쌓인 햄버거만 포장을 합니다. 상수는 손이 굉장히 빠르기 때문에 상수가 포장하는 동안 속 재료가 추가적으로 들어오는 일은 없으며, 재료의 높이는 무시하여 재료가 높이 쌓여서 일이 힘들어지는 경우는 없습니다.
#
# 예를 들어, 상수의 앞에 쌓이는 재료의 순서가 [야채, 빵, 빵, 야채, 고기, 빵, 야채, 고기, 빵]일 때, 상수는 여섯 번째 재료가 쌓였을 때, 세 번째 재료부터 여섯 번째 재료를 이용하여 햄버거를 포장하고, 아홉 번째 재료가 쌓였을 때, 두 번째 재료와 일곱 번째 재료부터 아홉 번째 재료를 이용하여 햄버거를 포장합니다. 즉, 2개의 햄버거를 포장하게 됩니다.
#
# 상수에게 전해지는 재료의 정보를 나타내는 정수 배열 ingredient가 주어졌을 때, 상수가 포장하는 햄버거의 개수를 return 하도록 solution 함수를 완성하시오.

# %%
def solution(ingredient):    # 풀이
    box = []
    cnt = 0
    for i in ingredient:
        box.append(i)   # 햄버거 재료를 하나씩 꺼내서 박스에 넣고
        if box[-4:] == [1,2,3,1]:   # 1231이 되면 cnt를 1올리고 box에서 햄버거를 삭제
            del box[-4:]
            cnt += 1
    return cnt

# %%
def solution(ingredient):
    s = []
    cnt = 0
    for i in ingredient:
        s.append(i)
        if s[-4:] == [1, 2, 3, 1]:  #다른 사람의 풀이. 다 비슷하고 마지막에 del을 쓰느냐 pop를 쓰느냐의 차이 정도? 
            cnt += 1
            for i in range(4):
                s.pop()
    return cnt

# %%
def solution(ingredient):        #다른 사람의 풀이2
    ingredient = "".join(list(map(str, ingredient))) #햄버거재료를 문자열로 교체
    if len(ingredient) < 4:                        # ingredient의 길이가 4보다 작다면 0을 return (햄버거가 성립되지 않으니까)
        return 0

    stack = ingredient[:3]                   #stack의 기본값을 햄버거의 앞 세자리로 집어넣음. (별로 필요 없어보이는 구간같음)
    count = 0
    for v in ingredient[3:]:
        stack += v
        if stack[-4:] == "1231":            #아래는 비슷한 풀이. 근데 정수를 문자열로 바꾸고 join하는건 상당히 괜찮은 방법인듯 직관적이고
            stack = stack[:-4]
            count += 1
    return count

# %%
def solution(ingredient):
    temp = []
    answer = 0
    for i in range(len(ingredient)):        # 다른 사람의 풀이 3
        temp.append(ingredient[i])          # 나랑 비슷한 풀이인데 ingredient이 아닌 len(ingredient)을 쓴 이유가 뭘까.
        if len(temp) >= 4:                  # 그냥 취향 차이인듯 잘 몰것다.
            if temp[-4::] == [1, 2, 3, 1]:
                answer += 1
                del temp[-4::]
    return answer

# %%
def solution(ingredient):
    answer = 0
    stack = []
    for i in ingredient:                #다른 사람의 풀이. 슬라이싱을 쓰면 깔끔할거갗은데 조금 파이써닉한 풀이는 아닌듯.
        if not stack:
            stack.append(i)
        else:
            if i == 1 and len(stack) > 3 and stack[-3] == 1 and stack[-2] == 2 and stack[-1] == 3:
                for i in range(3):
                    stack.pop()
                answer += 1
            else:
                stack.append(i)

    if stack:
        check = True

        while check:
            check = False

            if len(stack) >= 4 and stack[-1] == 1 and stack[-2] == 3 and stack[-3] == 2 and stack[-4] == 1:
                for i in range(4):
                    stack.pop()
                check = True
                answer += 1

    return answer

# %% [markdown]
# def solution(ingredient):
#     box = []
#     cnt = 0
#     for i in ingredient:
#         box.append(i)
#         if box[-4:] == [1,2,3,1]:
#             del box[-4:]
#             cnt += 1
#     return cnt
# 위 풀이를 조금 더 간결하게 적을수 있는 방법에 대해 생각해보자 (더럽게 간결한거 말고 깔끔하게 간결한걸로)

# %%
def solution(ingredient):
    box = ""
    cnt = 0
    for i in ingredient:
        box += str(i)
        if box[-4:] == "1231":
            cnt += 1
            box = box[:-4]
    return cnt
    #별로 간결한거같진 않은데.

# %% [markdown]
# 두 정수 X, Y의 임의의 자리에서 공통으로 나타나는 정수 k(0 ≤ k ≤ 9)들을 이용하여 만들 수 있는 가장 큰 정수를 두 수의 짝꿍이라 합니다(단, 공통으로 나타나는 정수 중 서로 짝지을 수 있는 숫자만 사용합니다). X, Y의 짝꿍이 존재하지 않으면, 짝꿍은 -1입니다. X, Y의 짝꿍이 0으로만 구성되어 있다면, 짝꿍은 0입니다.
#
# 예를 들어, X = 3403이고 Y = 13203이라면, X와 Y의 짝꿍은 X와 Y에서 공통으로 나타나는 3, 0, 3으로 만들 수 있는 가장 큰 정수인 330입니다. 다른 예시로 X = 5525이고 Y = 1255이면 X와 Y의 짝꿍은 X와 Y에서 공통으로 나타나는 2, 5, 5로 만들 수 있는 가장 큰 정수인 552입니다(X에는 5가 3개, Y에는 5가 2개 나타나므로 남는 5 한 개는 짝 지을 수 없습니다.)
# 두 정수 X, Y가 주어졌을 때, X, Y의 짝꿍을 return하는 solution 함수를 완성해주세요.
#
# 제한사항
# 3 ≤ X, Y의 길이(자릿수) ≤ 3,000,000입니다.
# X, Y는 0으로 시작하지 않습니다.
# X, Y의 짝꿍은 상당히 큰 정수일 수 있으므로, 문자열로 반환합니다.

# %%
def solution(X, Y):
    box_1 = list(X if len(X) >= len(Y) else Y)  #긴 문자열과 아닌 문자열을 우선 구분
    box_2 = list(Y if len(X) >= len(Y) else X)  
    result = []
    for s in box_1:                             # 긴문자열(box_1)에 box_2의 값이 들어있다면 result에 s를 추가후 box_2에서 s를 삭제(짝꿍)
        if s in box_2:
            result.append(s)
            box_2.remove(s)
    result = ''.join(sorted(result)[::-1])      #list result를 문자열로 교체 + 내림차순으로 변경
    if result and int(result) < 1:              #리스트가 null이 아니며 int(result)가 1보다 작을때 (0일때) "0"을 return
        return "0"              
    return result or "-1"                       #그게 아니면 result 값 or "-1"을 return

# %% [markdown]
# 아니 잠깐.
# 시간제한으로 몇몇문제가 패스가 안됨.
# 아마도
# X, Y의 짝꿍은 상당히 큰 정수일 수 있으므로, 문자열로 반환합니다. << 이 부분의 문제인거같음..
# if result and int(result) < 1:  여기서 result를 int로 바꿔서 비교하는데 힘을 다 쓴듯.

# %%
def solution(X, Y):
    box_1 = list(X if len(X) >= len(Y) else Y)  #긴 문자열
    box_2 = list(Y if len(X) >= len(Y) else X)  #아닌 문자열
    result = []
    for s in box_1:
        if s in box_2:
            result.append(s)
            box_2.remove(s)
    result = ''.join(sorted(result)[::-1])
    if set(result) == {'0'}:            #result에 0만 들어있으면 0을 return (int로 변환하지 않으니까 아까보다 나을거같다고 생각중)
        return '0'
    return result or '-1'

# %% [markdown]
# # 3 ≤ X, Y의 길이(자릿수) ≤ 3,000,000입니다.
# 여전히 시간초과가 뜬다.
# 최대 300만의 길이를 가지는걸 for문을 돌리고 if문을 돌리고 그걸 또 remove로 지워서 발생하는 문제로 보임..

# %%
def solution(X, Y):
    result = ''                             # 두 정수 X, Y의 임의의 자리에서 공통으로 나타나는 정수 k(0 ≤ k ≤ 9)
    for i in range(9, -1, -1):              # 9부터 1까지 내림차순으로 반복하니 정렬할 필요 X 
        i = str(i)                          # i를 str(i)로 변경 후 X와 Y의 공통되는 i중 min 값, cnt를 구함.
        cnt = min(X.count(i),Y.count(i))
        result += i * cnt                   #result 에 i(문자) 와 cnt를 곱한다. 
    if set(result) == {'0'}:                #만약 result가 0으로만 이루어져있다면 0을 return 그렇지 않다면 result 혹은 -1을 return 한다.
        return '0'
    else:
        return result or '-1'

# %%
def solution(X, Y):                                                 # 다른 사람의 풀이
    answer = ''

    for i in range(9,-1,-1) :                                       #거의 완벽히 똑같은 풀이인데 왜 이쪽이 더 간결해보이지 ?
        answer += (str(i) * min(X.count(str(i)), Y.count(str(i))))

    if answer == '' :
        return '-1'
    elif len(answer) == answer.count('0'):                          # answer의 길이와 0의 갯수를 비교하는 방식이 되게 참신하다.
        return '0'
    else :
        return answer                                               # collection 카운터 쓰세요. 그게 10배 빠릅니다. 카운트 실행할때마다 O(n) 이에요 (n=len(str))
                                                                    # 댓글에서 이런 내용을 발견. collection 카운터가 뭔소린진 잘 몰것는데 알아봐야겟음

# %% [markdown]
# # https://daleseo.com/python-collections-counter/
# 아하. 그러니까 collection 모듈의 counter라는 클래스는 변수내의 여러형태(!!)의 데이터를 딕셔너리 형태로 count해주는듯하다.
# 파이썬 3.7부터는 자동으로 내림차순이 적용되서 표시해준다고함.
# 근데 이게 count랑 다른게 뭐지.
# # counter(변수명).total() 형식으로 사용하면 len 처럼 사용할수도 있다고 함.
# # 서로 다른 두 counter 객체를 뺄수도 있다고 함 ( ex : counter1 - counter2 )
#
#
#
# # count와 counter의 차이점.
# count = 매번 문자열을 훑음. coutner = 딕셔너리 형식으로 저장 (어제 재귀함수 할때 만들었던 메모장처럼. 자체 메모기능 탑재)
# count는 호출할때마다 O(n) counter 는 처음 1회 O(n),이후로는 O(1), 그야 이미 만들었고 메모해둿으니까.
# count 는 호출할때마다 훑고 counter는 메모에서 꺼내 씀.
# count와 counter 모두 값을 못 찾을시 0 반환.
#
# 일반 딕셔너리는 없는 키를 찾을 경우 keyError
# counter는 0 반환.
# 흠
