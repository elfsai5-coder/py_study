# %%
    문제 설명
괄호가 바르게 짝지어졌다는 것은 '(' 문자로 열렸으면 반드시 짝지어서 ')' 문자로 닫혀야 한다는 뜻입니다. 예를 들어

"()()" 또는 "(())()" 는 올바른 괄호입니다.
")()(" 또는 "(()(" 는 올바르지 않은 괄호입니다.
'(' 또는 ')' 로만 이루어진 문자열 s가 주어졌을 때, 문자열 s가 올바른 괄호이면 true를 return 하고, 올바르지 않은 괄호이면 false를 return 하는 solution 함수를 완성해 주세요.

제한사항
문자열 s의 길이 : 100,000 이하의 자연수
문자열 s는 '(' 또는 ')' 로만 이루어져 있습니다.

# %%
def solution(s):
    return s[0] == '(' and s[-1] == ')'

    #이게 왜 아닌지 이해를 못하겟다 .문제 설명을 읽어보면 이거맞는거같은데. 한 네문제정도 패스가 안됨. 뭔가 더더욱 경우가 있나봄.
    #스택 쓰는 문제라고 되있는데 스택을 어떻게 써야할지 당장에 감도 안잡힘

# %%
def solution(s):
    box = []
    for ch in s:
        if ch == '(':               # box에 '('를 집어넣음
            box.append(ch)
        else:                       # 만약 ')'가 나왓을때 box가 비어있다면 False // ()가 성립이 안됨   
            if not box:             # 그 후 '('를 박스에서 하나 제거 (짝꿍이니까)
                return False
            box.pop()
    return len(box) == 0            # for문을 다 돌았을때 box의 길이가 0이라면 True (전부다 짝을 잘 찾은거니까)

# %%
def is_pair(s):                 # 다른 사람의 풀이.
    st = list()
    for c in s:
        if c == '(':
            st.append(c)

        if c == ')':
            try:
                st.pop()      # try, except를 문제 풀이에 쓴 사람을 처음봄
            except IndexError:
                return False

    return len(st) == 0

# %%
def is_pair(s):         # 다른 사람의 풀이2 
    pair = 0
    for x in s:
        if pair < 0: break          #pair가 음수가 된다면 즉시 브레이크 후 리턴으로 넘어가고 False가 나옴
        pair = pair + 1 if x == "(" else pair - 1 if x == ")" else pair     # 삼항연산자의 else안에 또다른 삼항연산을 박아넣어 가독성이 매우매우 구리다
    return pair == 0

# %% [markdown]
# 문제 설명
# 문자열 s에는 공백으로 구분된 숫자들이 저장되어 있습니다. str에 나타나는 숫자 중 최소값과 최대값을 찾아 이를 "(최소값) (최대값)"형태의 문자열을 반환하는 함수, solution을 완성하세요.
# 예를들어 s가 "1 2 3 4"라면 "1 4"를 리턴하고, "-1 -2 -3 -4"라면 "-4 -1"을 리턴하면 됩니다.
#
# 제한 조건
# s에는 둘 이상의 정수가 공백으로 구분되어 있습니다.
# 입출력 예
# s	return
# "1 2 3 4"	"1 4"
# "-1 -2 -3 -4"	"-4 -1"
# "-1 -1"	"-1 -1"

# %%
def solution(s):
    s = list(map(int,s.split()))        # s를 정수 + 리스트화 
    return f"{min(s)} {max(s)}"         # 중간에 띄어쓰기를 하기위해 f스트링

# %%
def solution(s):                        # 다른 사람의 풀이 
    s_list=s.split(" ")                 # s를 리스트 컴프리헨션을 이용해서 정수 리스트로 만든 후 정렬한 후 0번과 -1번만 쓰는 방식
    n = [int(i) for i in s_list]
    n.sort()

    return str(n[0]) + " " + str(n[len(n)-1])
