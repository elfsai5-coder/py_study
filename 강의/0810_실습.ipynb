# %%
fruits = ['apple', 'banana', 'cherry']
fruits[1] = 'blueberry'

fruits
# Out:
# ['apple', 'blueberry', 'cherry']

# %%
colors = ['red','green', 'blue']

colors[-1]
# Out:
# 'blue'

# %%
group1 = [1,2]
group2 = [3,4]

group1 + group2
# Out:
# [1, 2, 3, 4]

# %%
user_roles = ['admin', 'editor', 'member']

'admin' in user_roles
# Out:
# True

# %%
numbers = [i for i in range(6)]
numbers[:3]
# Out:
# [0, 1, 2]

# %%
num_list = [ i * 10 for i in range(1,5)]

first, *others = num_list
first,others
# Out:
# (10, [20, 30, 40])

# %%
user_info = { 
    'name' : 'Sparta',
    'age' : 20
}

user_info['age'] = 21
user_info['role'] = 'admin'
print(user_info.get('phone', "010-0000-0000"))
user_info
# Out:
# 010-0000-0000
# {'name': 'Sparta', 'age': 21, 'role': 'admin'}

# %%
raw_email = ["a@sparta.com", 'b@sparta.com', 'a@sparta.com']

raw_email = set(raw_email)

list(raw_email)
# Out:
# ['a@sparta.com', 'b@sparta.com']

# %%
menu = {"coffee" : 4000, 'tea' : 4500}

print(menu.keys())
print(menu.values())
# Out:
# dict_keys(['coffee', 'tea'])
# dict_values([4000, 4500])

# %%
set_a = {1, 2, 3}
set_b = {3, 4, 5}

print(set_a & set_b)
print(set_a | set_b)
set_a - set_b
# Out:
# {3}
# {1, 2, 3, 4, 5}
# {1, 2}
